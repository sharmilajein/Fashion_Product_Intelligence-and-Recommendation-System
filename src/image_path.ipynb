# %%
import os

for folder in os.listdir("/Users/jein/env/env/Fashion_product_intelligence/dataset_clean"):
    folder_path = os.path.join("/Users/jein/env/env/Fashion_product_intelligence/dataset_clean", folder)
    images = os.listdir(folder_path)
    if len(images) > 0:
        print("Sample image:", os.path.join(folder_path, images[0]))
        break
# Out:
# Sample image: /Users/jein/env/env/Fashion_product_intelligence/dataset_clean/Tshirts/12536.jpg
